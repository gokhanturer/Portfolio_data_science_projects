# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
import plotly.express as px

# %%
df = pd.read_csv("cleaned_auto_scouts.csv")

# %%
df.head().T
# Out:
#                                                                                0  \
# Unnamed: 0                                                                     0
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                        56013
# registration                                                             01/2016
# prev_owner                                                                   2.0
# hp                                                                          66.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     15919 non-null  int64
#  1   url                            15919 non-null  object
#  2   make_model                     15919 non-null  object
#  3   short_description              15873 non-null  object
#  4   body_type                      15859 non-null  object
#  5   price                          15919 non-null  int64
#  6   vat                            11406 non-null  object
#  7   km                             14895 non-null  float64
#  8   registration                   14322 non-null  datetime64[ns]
#  9   prev_owner                     10365 non-null  float64
#  10  hp                             15831 non-null  float64
#  11  Type                           15917 non-null  object
# ...

# %% [markdown]
# # Converting column data types  to numeric and datetime

# %%
df.price = pd.to_numeric(df.price)

# %%
df.km = df.km.str.replace("- ", "")

# %%
df.km = pd.to_numeric(df.km)

# %%
df.registration = df.registration.str.replace("-/-","")

# %%
df.registration = pd.to_datetime(df.registration)

# %%
df["Next Inspection"] = pd.to_datetime(df["Next Inspection"])

# %%
df.iloc[0:10,40:]
# Out:
#   Emission Label  Gears Country version  combined_fuel  city_fuel  \
# 0            NaN    NaN             NaN            3.8        4.3
# 1          Green    7.0             NaN            5.6        7.1
# 2          Green    NaN             NaN            3.8        4.4
# 3            NaN    6.0             NaN            3.8        4.3
# 4            NaN    NaN       'Germany'            4.1        4.6
# 5          Green    NaN       'Germany'            3.5        4.3
# 6            NaN    NaN       'Germany'            3.7        4.3
# 7            NaN    7.0             NaN            3.7        4.2
# 8            NaN    7.0             NaN            3.7        4.3
# 9            NaN    7.0             NaN            NaN        NaN
#
#    country_fuel
# 0           3.5
# 1           4.7
# 2           3.4
# 3           3.5
# 4           3.8
# 5           3.1
# 6           3.4
# 7           3.4
# 8           3.4
# 9           NaN

# %%
df.describe()
# Out:
#          Unnamed: 0         price             km    prev_owner            hp  \
# count  15919.000000  15919.000000   14895.000000  10365.000000  15831.000000
# mean    7959.000000  18019.896727   34130.127828      0.802701     88.367696
# std     4595.563803   7386.169409   37352.977568      0.564579     26.835135
# min        0.000000     13.000000       0.000000      0.000000      1.000000
# 25%     3979.500000  12850.000000    5153.000000      0.000000     66.000000
# 50%     7959.000000  16900.000000   22740.000000      1.000000     85.000000
# 75%    11938.500000  21900.000000   49371.500000      1.000000    101.000000
# max    15918.000000  74600.000000  317000.000000      4.000000    294.000000
#
#        First Registration  Nr. of Doors  Nr. of Seats  Displacement  \
# count        14322.000000  15707.000000  15707.000000  15423.000000
# mean          2017.457618      4.656077      4.656077   1423.540881
# std              1.076917      0.645298      0.645298    333.530658
# ...

# %% [markdown]
# # Handling with Missing Values and Outliers

# %%
sns.boxplot(x = df.combined_fuel)
# Out:
# <AxesSubplot:xlabel='combined_fuel'>

# %%
sns.histplot(x = df.combined_fuel, kde=True, bins=50)
# Out:
# <AxesSubplot:xlabel='combined_fuel', ylabel='Count'>

# %%
px.box(x = df.combined_fuel)
# Out:
# <div>                            <div id="9a5bd6f7-18bb-476f-94a0-97c04cfc2da8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a5bd6f7-18bb-476f-94a0-97c04cfc2da8")) {                    Plotly.newPlot(                        "9a5bd6f7-18bb-476f-94a0-97c04cfc2da8",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"type":"box","x":[3.8,5.6,3.8,3.8,4.1,3.5,3.7,3.7,3.7,null,4.6,4.9,4.9,null,4.2,3.7,3.5,3.8,4.5,3.8,4.6,4.9,4.9,3.7,4.4,4.2,4.2,4.2,4.3,4.4,null,3.6,4.4,3.7,3.7,4.4,4.4,3.7,4.2,null,4.4,3.4,3.4,null,3.6,4.2,3.7,3.7,4.4,4.4,null,4.2,4.2,null,3.8,4.4,4.2,4.4,3.8,4.2,3.7,4.4,4.2
# ...

# %%
df[df.combined_fuel==1.6]
# Out:
#       Unnamed: 0                                                url  \
# 3612        3612  https://www.autoscout24.com//offers/audi-a3-sp...
# 3615        3615  https://www.autoscout24.com//offers/audi-a3-sp...
# 3617        3617  https://www.autoscout24.com//offers/audi-a3-sp...
#
#      make_model                      short_description body_type  price  \
# 3612    Audi A3  SPB 1.4 TFSI e-tron S tronic (PHEV) S    Sedans  38450
# 3615    Audi A3  SPB 1.4 TFSI e-tron S tronic (PHEV) S    Sedans  35899
# 3617    Audi A3  SPB 1.4 TFSI e-tron S tronic (PHEV) D    Sedans  38000
#
#                    vat       km registration  prev_owner  ...  \
# 3612  Price negotiable  13800.0   2018-02-01         NaN  ...
# 3615               NaN  20880.0   2018-05-01         NaN  ...
# 3617  Price negotiable  12000.0   2018-02-01         1.0  ...
#
#                                           Entertainment  \
# 3612  'Bluetooth', 'CD player', 'Digital radio', 'Ha...
# ...

# %%
df[df.make_model=="Audi A3" ]["combined_fuel"].describe()
# Out:
# count    2753.00000
# mean        4.43211
# std         0.66583
# min         1.60000
# 25%         3.90000
# 50%         4.40000
# 75%         4.70000
# max         8.30000
# Name: combined_fuel, dtype: float64

# %%
df.combined_fuel = df.combined_fuel.apply(lambda x:4.43211 if x<2 else x )

# %%
px.box(x = df.combined_fuel)
# Out:
# <div>                            <div id="ace78646-8456-4b92-858f-c71fcd547294" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ace78646-8456-4b92-858f-c71fcd547294")) {                    Plotly.newPlot(                        "ace78646-8456-4b92-858f-c71fcd547294",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"type":"box","x":[3.8,5.6,3.8,3.8,4.1,3.5,3.7,3.7,3.7,null,4.6,4.9,4.9,null,4.2,3.7,3.5,3.8,4.5,3.8,4.6,4.9,4.9,3.7,4.4,4.2,4.2,4.2,4.3,4.4,null,3.6,4.4,3.7,3.7,4.4,4.4,3.7,4.2,null,4.4,3.4,3.4,null,3.6,4.2,3.7,3.7,4.4,4.4,null,4.2,4.2,null,3.8,4.4,4.2,4.4,3.8,4.2,3.7,4.4,4.2
# ...

# %%
df[df.combined_fuel>16]
# Out:
#        Unnamed: 0                                                url  \
# 10513       10513  https://www.autoscout24.com//offers/opel-insig...
#
#           make_model                        short_description      body_type  \
# 10513  Opel Insignia  2.8 OPC 4x4 Turbo Sports Navi/Leder/Xen  Station wagon
#
#        price             vat        km registration  prev_owner  ...  \
# 10513  17990  VAT deductible  145000.0   2016-04-01         1.0  ...
#
#                                            Entertainment  \
# 10513  'Bluetooth', 'CD player', 'Digital radio', 'Ha...
#
#                                                   Extras  \
# 10513  'Alloy wheels', 'Roof rack', 'Shift paddles', ...
#
#                            safety_first_operation_always  \
# 10513  'ABS', 'Adaptive Cruise Control', 'Blind spot ...
#
#                                              description Emission Label Gears  \
# 10513  'DAB-Tuner (Radioempfang digital) Frontkamera ...          Green   NaN
#
# ...

# %%
df[df.make_model == "Opel Insignia"]
# Out:
#        Unnamed: 0                                                url  \
# 10457       10457  https://www.autoscout24.com//offers/opel-insig...
# 10458       10458  https://www.autoscout24.com//offers/opel-insig...
# 10459       10459  https://www.autoscout24.com//offers/opel-insig...
# 10460       10460  https://www.autoscout24.com//offers/opel-insig...
# 10461       10461  https://www.autoscout24.com//offers/opel-insig...
# ...           ...                                                ...
# 13050       13050  https://www.autoscout24.com//offers/opel-insig...
# 13051       13051  https://www.autoscout24.com//offers/opel-insig...
# 13052       13052  https://www.autoscout24.com//offers/opel-insig...
# 13053       13053  https://www.autoscout24.com//offers/opel-insig...
# 13054       13054  https://www.autoscout24.com//offers/opel-insig...
#
#           make_model                               short_description  \
# ...

# %%
df[df.make_model=="Opel Insignia" ]["combined_fuel"].describe()
# Out:
# count    2096.000000
# mean        5.498378
# std         0.982747
# min         3.600000
# 25%         4.800000
# 50%         5.600000
# 75%         6.100000
# max        16.100000
# Name: combined_fuel, dtype: float64

# %%
df.combined_fuel = df.combined_fuel.apply(lambda x:5.498378 if x>15 else x )

# %%
df[df.combined_fuel>7]
# Out:
#        Unnamed: 0                                                url  \
# 535           535  https://www.autoscout24.com//offers/audi-a1-1-...
# 713           713  https://www.autoscout24.com//offers/audi-a1-sp...
# 1926         1926  https://www.autoscout24.com//offers/audi-a1-sp...
# 1958         1958  https://www.autoscout24.com//offers/audi-a1-sp...
# 2173         2173  https://www.autoscout24.com//offers/audi-a1-sp...
# ...           ...                                                ...
# 15889       15889  https://www.autoscout24.com//offers/renault-es...
# 15900       15900  https://www.autoscout24.com//offers/renault-es...
# 15906       15906  https://www.autoscout24.com//offers/renault-es...
# 15907       15907  https://www.autoscout24.com//offers/renault-es...
# 15915       15915  https://www.autoscout24.com//offers/renault-es...
#
#            make_model                                  short_description  \
# ...

# %%
df[df.make_model=="Audi A1"]
# Out:
#       Unnamed: 0                                                url  \
# 0              0  https://www.autoscout24.com//offers/audi-a1-sp...
# 1              1  https://www.autoscout24.com//offers/audi-a1-1-...
# 2              2  https://www.autoscout24.com//offers/audi-a1-sp...
# 3              3  https://www.autoscout24.com//offers/audi-a1-1-...
# 4              4  https://www.autoscout24.com//offers/audi-a1-sp...
# ...          ...                                                ...
# 2609        2609  https://www.autoscout24.com//offers/audi-a1-sb...
# 2610        2610  https://www.autoscout24.com//offers/audi-a1-sp...
# 2611        2611  https://www.autoscout24.com//offers/audi-a1-sp...
# 2612        2612  https://www.autoscout24.com//offers/audi-a1-sp...
# 2613        2613  https://www.autoscout24.com//offers/audi-a1-25...
#
#      make_model                                  short_description body_type  \
# ...

# %%
#gears number 0-9

# %%
df[df.price<1000.0]
# Out:
#       Unnamed: 0                                                url  \
# 6066        6066  https://www.autoscout24.com//offers/opel-astra...
# 8594        8594  https://www.autoscout24.com//offers/opel-corsa...
# 8828        8828  https://www.autoscout24.com//offers/opel-corsa...
# 8829        8829  https://www.autoscout24.com//offers/opel-corsa...
#
#       make_model                               short_description  \
# 6066  Opel Astra  1.6 D (CDTI) Start/Stop Sports Tourer Business
# 8594  Opel Corsa             1.4 (ecoFLEX) Start/Stop Innovation
# 8828  Opel Corsa     1.0 Turbo 120 Jaar Edition / 120 EURO p/mnd
# 8829  Opel Corsa   Corsa1.0 Turbo 90 Pk OPC Line | Private Lease
#
#           body_type  price  vat      km registration  prev_owner  ...  \
# 6066  Station wagon    255  NaN  5563.0   2018-06-01         NaN  ...
# 8594         Sedans     13  NaN   123.0   2018-06-01         NaN  ...
# 8828        Compact    120  NaN    12.0   2019-01-01         0.0  ...
# ...

# %%
df[df.make_model=="Opel Corsa"]
# Out:
#        Unnamed: 0                                                url  \
# 8238         8238  https://www.autoscout24.com//offers/opel-corsa...
# 8239         8239  https://www.autoscout24.com//offers/opel-corsa...
# 8240         8240  https://www.autoscout24.com//offers/opel-corsa...
# 8241         8241  https://www.autoscout24.com//offers/opel-corsa...
# 8242         8242  https://www.autoscout24.com//offers/opel-corsa...
# ...           ...                                                ...
# 10452       10452  https://www.autoscout24.com//offers/opel-corsa...
# 10453       10453  https://www.autoscout24.com//offers/opel-corsa...
# 10454       10454  https://www.autoscout24.com//offers/opel-corsa...
# 10455       10455  https://www.autoscout24.com//offers/opel-corsa...
# 10456       10456  https://www.autoscout24.com//offers/opel-corsa...
#
#        make_model                                short_description body_type  \
# ...

# %%
# Since combined fuel consists of both country and city fuel.
# It is not appropriate to use all these three columns in our model. So we will focus on combined fuel col.

# %%
NaN

# %%
df[df.country_fuel>df.city_fuel]
# Out:
#        Unnamed: 0                                                url  \
# 1644         1644  https://www.autoscout24.com//offers/audi-a1-sp...
# 1839         1839  https://www.autoscout24.com//offers/audi-a1-sp...
# 8691         8691  https://www.autoscout24.com//offers/opel-corsa...
# 9538         9538  https://www.autoscout24.com//offers/opel-corsa...
# 10309       10309  https://www.autoscout24.com//offers/opel-corsa...
# 13112       13112  https://www.autoscout24.com//offers/renault-cl...
# 13121       13121  https://www.autoscout24.com//offers/renault-cl...
# 13235       13235  https://www.autoscout24.com//offers/renault-cl...
# 14064       14064  https://www.autoscout24.com//offers/renault-cl...
#
#          make_model                                  short_description  \
# 1644        Audi A1                  Sportback 1.4 TFSI S tronic sport
# 1839        Audi A1        Sportback 1.4 TDI NAVI+ Xenon 2x PDC Design
# ...

# %%
df.isna()
# Out:
#        Unnamed: 0    url  make_model  short_description  body_type  price  \
# 0           False  False       False              False      False  False
# 1           False  False       False              False      False  False
# 2           False  False       False              False      False  False
# 3           False  False       False              False      False  False
# 4           False  False       False              False      False  False
# ...           ...    ...         ...                ...        ...    ...
# 15914       False  False       False              False      False  False
# 15915       False  False       False              False      False  False
# 15916       False  False       False              False      False  False
# 15917       False  False       False              False      False  False
# 15918       False  False       False              False      False  False
#
#          vat     km  registration  prev_owner  ...  Entertainment  Extras  \
# ...

# %%
df[(df.make_model== "Opel Corsa") & (df.km<300)].describe()
# Out:
#          Unnamed: 0         price          km  prev_owner          hp  \
# count    558.000000    558.000000  558.000000  441.000000  558.000000
# mean    9980.679211  13056.111111   22.632616    0.063492   59.173835
# std      471.373785   2777.605869   35.589463    0.253262    7.368249
# min     8264.000000     13.000000    0.000000    0.000000   40.000000
# 25%     9893.000000  10900.000000    8.000000    0.000000   51.000000
# 50%    10100.500000  11400.000000   10.000000    0.000000   66.000000
# 75%    10280.750000  15490.000000   15.000000    0.000000   66.000000
# max    10456.000000  18622.000000  250.000000    2.000000   74.000000
#
#        First Registration  Nr. of Doors  Nr. of Seats  Displacement  \
# count          458.000000    552.000000    552.000000    557.000000
# mean          2018.901747      4.054348      4.054348   1322.605027
# std              0.305237      0.958645      0.958645    102.322026
# ...

# %%
df.price = df.price.apply(lambda x: 13056 if x <1000 else x)

# %%
df[df.price< 1000]
# Out:
#       Unnamed: 0                                                url  \
# 6066        6066  https://www.autoscout24.com//offers/opel-astra...
# 8828        8828  https://www.autoscout24.com//offers/opel-corsa...
# 8829        8829  https://www.autoscout24.com//offers/opel-corsa...
#
#       make_model                               short_description  \
# 6066  Opel Astra  1.6 D (CDTI) Start/Stop Sports Tourer Business
# 8828  Opel Corsa     1.0 Turbo 120 Jaar Edition / 120 EURO p/mnd
# 8829  Opel Corsa   Corsa1.0 Turbo 90 Pk OPC Line | Private Lease
#
#           body_type  price  vat      km registration  prev_owner  ...  \
# 6066  Station wagon    255  NaN  5563.0   2018-06-01         NaN  ...
# 8828        Compact    120  NaN    12.0   2019-01-01         0.0  ...
# 8829          Other    331  NaN    10.0   2019-01-01         0.0  ...
#
#                                           Entertainment  \
# 6066  'Bluetooth', 'Hands-free equipment', 'On-board...
# ...

# %%
px.box(df.price)
# Out:
# <div>                            <div id="d9a5d28f-f5d2-4525-9705-c46d4eeee5e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9a5d28f-f5d2-4525-9705-c46d4eeee5e4")) {                    Plotly.newPlot(                        "d9a5d28f-f5d2-4525-9705-c46d4eeee5e4",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"type":"box","x":["price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","price","pric
# ...

# %%
df[df.price> 40000]
# Out:
#        Unnamed: 0                                                url  \
# 3587         3587  https://www.autoscout24.com//offers/audi-a3-rs...
# 3590         3590  https://www.autoscout24.com//offers/audi-a3-rs...
# 3592         3592  https://www.autoscout24.com//offers/audi-a3-rs...
# 3593         3593  https://www.autoscout24.com//offers/audi-a3-rs...
# 3594         3594  https://www.autoscout24.com//offers/audi-a3-s3...
# ...           ...                                                ...
# 15900       15900  https://www.autoscout24.com//offers/renault-es...
# 15901       15901  https://www.autoscout24.com//offers/renault-es...
# 15902       15902  https://www.autoscout24.com//offers/renault-es...
# 15904       15904  https://www.autoscout24.com//offers/renault-es...
# 15918       15918  https://www.autoscout24.com//offers/renault-es...
#
#            make_model                                  short_description  \
# ...

# %%
df[df.km>150000]
# Out:
#        Unnamed: 0                                                url  \
# 63             63  https://www.autoscout24.com//offers/audi-a1-s-...
# 602           602  https://www.autoscout24.com//offers/audi-a1-sp...
# 2637         2637  https://www.autoscout24.com//offers/audi-a3-sp...
# 2745         2745  https://www.autoscout24.com//offers/audi-a3-sp...
# 2813         2813  https://www.autoscout24.com//offers/audi-a3-2-...
# ...           ...                                                ...
# 15278       15278  https://www.autoscout24.com//offers/renault-es...
# 15282       15282  https://www.autoscout24.com//offers/renault-es...
# 15283       15283  https://www.autoscout24.com//offers/renault-es...
# 15314       15314  https://www.autoscout24.com//offers/renault-es...
# 15320       15320  https://www.autoscout24.com//offers/renault-es...
#
#            make_model                              short_description  \
# ...

# %%
# I will keep " km" outliers since they are real values when I analyze the price column.

# %% [markdown]
# px.box(df.hp)

# %%
df[df.hp<40][["make_model", "km", "combined_fuel", "hp", "price"]]
# Out:
#            make_model       km  combined_fuel   hp  price
# 3913          Audi A3  24000.0            NaN  9.0  20440
# 6005       Opel Astra  73860.0            NaN  1.0  11600
# 6034       Opel Astra  76010.0            NaN  1.0  11600
# 6946       Opel Astra  70090.0            NaN  1.0  11900
# 7014       Opel Astra  79993.0            NaN  1.0  11700
# 7016       Opel Astra  62384.0            NaN  1.0  11700
# 7018       Opel Astra  77272.0            NaN  1.0  11700
# 7019       Opel Astra  69035.0            NaN  1.0  11700
# 9285       Opel Corsa  58912.0            NaN  1.0   8300
# 9287       Opel Corsa  53522.0            NaN  1.0   8300
# 9288       Opel Corsa  60386.0            NaN  1.0   8300
# 9289       Opel Corsa  59217.0            NaN  1.0   8300
# 9290       Opel Corsa  51318.0            NaN  1.0   8300
# 9292       Opel Corsa  53390.0            NaN  1.0   8300
# 9299       Opel Corsa  47140.0            NaN  1.0   8300
# ...

# %%
df[df.make_model=="Audi A3"]["hp"].describe()
# Out:
# count    3096.000000
# mean       90.194121
# std        19.951041
# min         9.000000
# 25%        81.000000
# 50%        85.000000
# 75%        85.000000
# max       294.000000
# Name: hp, dtype: float64

# %%
df.hp  = df.hp.apply(lambda x: 90.194121 if x<40 else x)

# %%
px.box(df.hp)
# Out:
# <div>                            <div id="f91a265f-b63d-4d9b-9032-a838b44800eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f91a265f-b63d-4d9b-9032-a838b44800eb")) {                    Plotly.newPlot(                        "f91a265f-b63d-4d9b-9032-a838b44800eb",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"type":"box","x":["hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","hp","h
# ...

# %%
sns.countplot(df["Nr. of Doors"])
# Out:
# C:\Users\CASPER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Nr. of Doors', ylabel='count'>

# %%
df[df["Nr. of Doors"]==2][["make_model", "Nr. of Doors","short_description"]]make
# Out:
#        make_model  Nr. of Doors                              short_description
# 26        Audi A1           2.0              1.0 TFSI *PDC*SHZ*Klimaautomatik*
# 44        Audi A1           2.0                        Sportback 1.0 TDI ultra
# 48        Audi A1           2.0         SPORT KLIMA+SHZ+PDC+16-ZOLL-ALU+EURO 6
# 55        Audi A1           2.0            basis/ 169,-¤ Monatl. Finanzi. Rate
# 56        Audi A1           2.0  1.0 TFSI ultra *8Fach Bereift*Klima*RADIO CD*
# ...           ...           ...                                            ...
# 10304  Opel Corsa           2.0       E 1.2 Selection - NEU ohne Erstzulassung
# 10314  Opel Corsa           2.0           1.2 Selection Klimaanl.+Allwetter+CD
# 10380  Opel Corsa           2.0                   1.2 Selection Klima Radio BT
# 10413  Opel Corsa           2.0       E 1.2 Selection,RIESENAUSWAHL bei JÖST !
# 10444  Opel Corsa           2.0                   1.2 Selection Klima Radio BT
#
# [219 rows x 3 columns]

# %%
dfdoor = df[df["Nr. of Doors"]==2][["make_model", "Nr. of Doors","short_description"]]

# %%
sns.barplot(x=dfdoor["Nr. of Doors"], y =dfdoor["make_model"] )
# Out:
# <AxesSubplot:xlabel='Nr. of Doors', ylabel='make_model'>

# %%
df[df["make_model"]=="Audi A1"][["Nr. of Doors","short_description"]]
# Out:
#       Nr. of Doors                                  short_description
# 0              5.0        Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1              3.0                                     1.8 TFSI sport
# 2              4.0  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...
# 3              3.0                            1.4 TDi Design S tronic
# 4              5.0  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...
# ...            ...                                                ...
# 2609           5.0                            SB 25 1.0 tfsi Advanced
# 2610           5.0  Sportback 1.4 TFSI 125 PS-Garantie 4 Jahre-Kli...
# 2611           5.0  SPORTBACK 95PK TFSI ULTRA"S-LINE"PRACHTUITVOERING
# 2612           5.0      Sportback Sport 1.0TFSI Klimaaut. Sitzhzg EPH
# 2613           4.0                                            25 TFSI
#
# [2614 rows x 2 columns]

# %%
desc = df.short_description.unique()

# %%
def door_assigner(x):
# Out:
# Sportback 1.4 TDI S-tronic Xenon Navi Klima
# 1.8 TFSI sport
# Sportback 1.6 TDI S tronic Einparkhilfe plus+music
# 1.4 TDi Design S tronic
# Sportback 1.4 TDI S-Tronic S-Line Ext. admired, Xe
# 1.6 TDI Sport DSG *SHZ*Xenon*Navi*Bose*PDC*
# Sportback 1.6 TDI S-TRONIC S-LINE*NAVI|XENON*
# Sportback 1.4 TDI admired S tronic
# SPB 1.6 TDI S-tronic Metal plus + Xeno
# SPORTBACK TFSI ULTRA 95 S-TRONIC AMB.
# SPORTBACK1.6 TDI 116 CV S tronic Metal plus
# Sportback Sport »1.4 TFSI|Xenon|Navi|EPH+|SHZ|S tr
# Sportback 1.4 TFSI S-tronic *S line*NAV*XEN*
# 1.4 TFSI 150ch COD Ambition Luxe S tronic 7
# Sportback 1.0 TFSI S-TRonic*Navi*Xenon*APS* Sport
# SPB 1.6 TDI 116 CV S tronic Sport
# SPB 1.6 TDI 116 CV Design S-Line SPB 1.6 TDI 116 C
# 1.4 TDi S tronic*S-Line*Navigatie*Euro 6b*
# 1.0 TFSI 95pk Automaat Adrenalin
# Sportback 1.6 TDI 116 CV S tronic Metal plus
# SPB 1.6 TDI 116 CV S tronic Admired S-Line
# Sportback Sport 1.4 TFSI S tronic XENON NAVI
# 1.4 TFSI S tronic
# ...

# %%
df[df["Nr. of Doors"]==4]["make_model"].value_counts()
# Out:
# Opel Insignia     708
# Audi A3           634
# Audi A1           536
# Opel Astra        533
# Opel Corsa        291
# Renault Clio      272
# Renault Espace    105
# Name: make_model, dtype: int64

# %%
df["Nr. of Doors"] = df["Nr. of Doors"].apply(lambda x: 5 if x==4 else x)

# %%
df["Nr. of Doors"] = df["Nr. of Doors"].apply(lambda x: 3 if x==2 else x)

# %%
sns.countplot(df["Nr. of Doors"])
# Out:
# C:\Users\CASPER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Nr. of Doors', ylabel='count'>

# %%
df[df["Nr. of Doors"] ==1]
# Out:
#        Unnamed: 0                                                url  \
# 13782       13782  https://www.autoscout24.com//offers/renault-cl...
#
#          make_model                   short_description body_type  price  \
# 13782  Renault Clio  Business Energy dCi 75 eco2 Euro 6   Compact   8500
#
#                   vat       km registration  prev_owner  ...  Entertainment  \
# 13782  VAT deductible  41493.0   2016-01-01         NaN  ...            NaN
#
#       Extras safety_first_operation_always  \
# 13782    NaN                           NaN
#
#                                              description Emission Label Gears  \
# 13782  'Financiado desde ', '155,36 €', '/mes', 'Cond...            NaN   NaN
#
#       Country version  combined_fuel city_fuel country_fuel
# 13782             NaN            NaN       NaN          NaN
#
# [1 rows x 46 columns]

# %%
df[df["make_model"] =="Renault Clio"]["Nr. of Doors"].value_counts()
# Out:
# 5.0    1794
# 1.0       1
# Name: Nr. of Doors, dtype: int64

# %%
df["Nr. of Doors"] = df["Nr. of Doors"].apply(lambda x: 5 if x==1 else x)

# %%
df[df["Nr. of Doors"] ==7]
# Out:
#        Unnamed: 0                                                url  \
# 15202       15202  https://www.autoscout24.com//offers/renault-es...
#
#            make_model short_description body_type  price               vat  \
# 15202  Renault Espace    Initiale Paris       Van  21600  Price negotiable
#
#             km registration  prev_owner  ...  \
# 15202  78000.0   2016-04-01         NaN  ...
#
#                                            Entertainment  \
# 15202  'Bluetooth', 'Digital radio', 'MP3', 'On-board...
#
#                                Extras  \
# 15202  'Alloy wheels', 'Touch screen'
#
#                            safety_first_operation_always description  \
# 15202  'ABS', 'Blind spot monitor', 'Central door loc...         NaN
#
#       Emission Label Gears Country version  combined_fuel city_fuel  \
# 15202            NaN   6.0             NaN            4.6       4.4
#
#       country_fuel
# 15202          NaN
#
# [1 rows x 46 columns]

# %%
df["Nr. of Doors"] = df["Nr. of Doors"].apply(lambda x: 5 if x==7 else x)

# %%
df.describe()
# Out:
#          Unnamed: 0         price             km    prev_owner            hp  \
# count  15919.000000  15919.000000   14895.000000  10365.000000  15831.000000
# mean    7959.000000  18023.132169   34130.127828      0.802701     88.490953
# std     4595.563803   7381.171893   37352.977568      0.564579     26.638740
# min        0.000000   4950.000000       0.000000      0.000000     40.000000
# 25%     3979.500000  12850.000000    5153.000000      0.000000     66.000000
# 50%     7959.000000  16900.000000   22740.000000      1.000000     85.000000
# 75%    11938.500000  21900.000000   49371.500000      1.000000    101.000000
# max    15918.000000  74600.000000  317000.000000      4.000000    294.000000
#
#        First Registration  Nr. of Doors  Nr. of Seats  Displacement  \
# count        14322.000000  15707.000000  15707.000000  15423.000000
# mean          2017.457618      4.866174      4.656077   1423.540881
# std              1.076917      0.499758      0.645298    333.530658
# ...

# %%
sns.countplot(df["Nr. of Seats"])
# Out:
# C:\Users\CASPER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Nr. of Seats', ylabel='count'>

# %%
dfseats = df[df["Nr. of Seats"]==2]

# %%
sns.barplot(x = dfseats["Nr. of Seats"], y = dfseats["Nr. of Doors"])
# Out:
# <AxesSubplot:xlabel='Nr. of Seats', ylabel='Nr. of Doors'>

# %%
# It shows us all 2 seated cars have 3 doors. So no problem

# %%
dfseats2 = df[df["Nr. of Seats"]==3]

# %%
sns.barplot(x = dfseats2["Nr. of Seats"], y = dfseats2["Nr. of Doors"])
# Out:
# <AxesSubplot:xlabel='Nr. of Seats', ylabel='Nr. of Doors'>

# %%
px.box (df.Displacement)
# Out:
# <div>                            <div id="d9c00265-52b8-4e33-9860-026ecf9bdc8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9c00265-52b8-4e33-9860-026ecf9bdc8f")) {                    Plotly.newPlot(                        "d9c00265-52b8-4e33-9860-026ecf9bdc8f",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"type":"box","x":["Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacement","Displacemen
# ...

# %%
df.Displacement.value_counts()
# Out:
# 1598.0    4761
# 999.0     2438
# 1398.0    1314
# 1399.0     749
# 1229.0     677
#           ...
# 122.0        1
# 140.0        1
# 1390.0       1
# 54.0         1
# 1533.0       1
# Name: Displacement, Length: 77, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     15919 non-null  int64
#  1   url                            15919 non-null  object
#  2   make_model                     15919 non-null  object
#  3   short_description              15873 non-null  object
#  4   body_type                      15859 non-null  object
#  5   price                          15919 non-null  int64
#  6   vat                            11406 non-null  object
#  7   km                             14895 non-null  float64
#  8   registration                   14322 non-null  datetime64[ns]
#  9   prev_owner                     10365 non-null  float64
#  10  hp                             15831 non-null  float64
#  11  Type                           15917 non-null  object
# ...

# %%
df["Offer Number"].value_counts()
# Out:
# UN89904                                 27
# TP62881                                 27
# AK13780                                 27
# HM53619                                 27
# XT61649                                 27
#                                         ..
# 00-38-14018                              1
# 11806896                                 1
# bfed1a2e-f885-46b6-a653-df7db4d2261c     1
# 10574-MUE                                1
# KD700Z                                   1
# Name: Offer Number, Length: 11440, dtype: int64

# %%
df.Fuel
# Out:
# 0        Diesel Particulate Filter
# 1                         Gasoline
# 2        Diesel Particulate Filter
# 3        Diesel Particulate Filter
# 4        Diesel Particulate Filter
#                    ...
# 15914    Diesel Particulate Filter
# 15915                  Super,Super
# 15916                       Diesel
# 15917                       Diesel
# 15918                        Super
# Name: Fuel, Length: 15919, dtype: object

# %%
df.combined_fuel.value_counts()
# Out:
# 5.400000     770
# 4.500000     763
# 3.900000     733
# 4.700000     720
# 4.400000     665
# 5.100000     663
# 5.600000     626
# 3.800000     587
# 4.800000     565
# 4.200000     526
# 4.600000     498
# 4.900000     460
# 5.200000     455
# 6.300000     413
# 5.900000     404
# 5.500000     398
# 5.300000     380
# 3.700000     370
# 5.700000     355
# 4.300000     346
# 4.100000     345
# 3.300000     327
# 3.500000     307
# 6.200000     228
# 3.600000     195
# 5.800000     194
# 6.100000     187
# 6.600000     151
# 3.400000     144
# 6.800000     138
# 7.800000     131
# 6.500000      83
# 6.400000      83
# 7.400000      68
# 6.700000      47
# 7.100000      39
# 7.300000      32
# 7.600000      31
# 7.700000      27
# 6.900000      27
# 3.200000      25
# 8.300000      20
# 7.500000      15
# 7.900000      11
# 8.200000      11
# 7.200000       8
# 3.100000       7
# 4.432110       4
# 8.600000       4
# 8.700000       3
# 9.500000       3
# 8.100000       2
# ...
